# %% [markdown]
# # HR/LR dataset creation
#
# Extracts frames from the source videos, crops them to the object and writes
# each HR image next to its degraded LR counterpart.
#
# The logic lives in `srlib/dataset/builder.py` and the knobs live in
# `srlib/constants.py`: the degradation seed picks *which* dataset is drawn
# and the degradation config picks *how* degraded it is. To search for a
# realistic LR dataset, tune the config there, delete `data/images/HR`,
# `data/images/LR` and `data/metadata/degradation_log.json`, and re-run this
# notebook.

# %%
import os
import sys

sys.path.append(os.path.abspath(os.path.join(os.getcwd(), "../")))

from srlib.dataset.builder import build_dataset_from_videos
from srlib.dataset.visualization import plot_hr_lr_samples

# %% [markdown]
# ## Build the dataset

# %%
# Defaults come from constants: which folders to walk, how many videos to
# take from each, the frame interval, the class ids, the degradation seed and
# config, and whether to replay the recorded log instead of sampling.
summary = build_dataset_from_videos()
# Out:
# [low_z_offset] class 0 | 12 video(s), one frame every 80
#   (1/12) low_z_offset_1.mp4
# === VIDEO ANALYSIS ===
# Video: c:\Users\bgmanuel\MasterInteligenciaArtificial\Periodo2\TFM\Super-Resolution-Images-for-3D-Printing-Defect-Detection\data\videos\low_z_offset\low_z_offset_1.mp4
# Total frames: 1597
# Images saved in this run: 20
# Total images in directory: 20
# Original HR frame size (width x height): 478 x 850
# Cropped HR frame size (width x height): 478 x 478
# LR frame size (width x height): 239 x 239
#   (2/12) low_z_offset_10.mp4
# === VIDEO ANALYSIS ===
# Video: c:\Users\bgmanuel\MasterInteligenciaArtificial\Periodo2\TFM\Super-Resolution-Images-for-3D-Printing-Defect-Detection\data\videos\low_z_offset\low_z_offset_10.mp4
# Total frames: 1136
# Images saved in this run: 15
# Total images in directory: 35
# Original HR frame size (width x height): 478 x 850
# Cropped HR frame size (width x height): 478 x 478
# LR frame size (width x height): 239 x 239
#   (3/12) low_z_offset_11.mp4
# === VIDEO ANALYSIS ===
# Video: c:\Users\bgmanuel\MasterInteligenciaArtificial\Periodo2\TFM\Super-Resolution-Images-for-3D-Printing-Defect-Detection\data\videos\low_z_offset\low_z_offset_11.mp4
# Total frames: 1397
# Images saved in this run: 18
# Total images in directory: 53
# Original HR frame size (width x height): 478 x 850
# Cropped HR frame size (width x height): 478 x 478
# LR frame size (width x height): 239 x 239
#   (4/12) low_z_offset_12.mp4
# === VIDEO ANALYSIS ===
# Video: c:\Users\bgmanuel\MasterInteligenciaArtificial\Periodo2\TFM\Super-Resolution-Images-for-3D-Printing-Defect-Detection\data\videos\low_z_offset\low_z_offset_12.mp4
# Total frames: 1461
# Images saved in this run: 19
# Total images in directory: 72
# Original HR frame size (width x height): 478 x 850
# Cropped HR frame size (width x height): 478 x 478
# LR frame size (width x height): 239 x 239
#   (5/12) low_z_offset_2.mp4
# === VIDEO ANALYSIS ===
# Video: c:\Users\bgmanuel\MasterInteligenciaArtificial\Periodo2\TFM\Super-Resolution-Images-for-3D-Printing-Defect-Detection\data\videos\low_z_offset\low_z_offset_2.mp4
# Total frames: 1268
# Images saved in this run: 16
# Total images in directory: 88
# Original HR frame size (width x height): 478 x 850
# Cropped HR frame size (width x height): 478 x 478
# LR frame size (width x height): 239 x 239
#   (6/12) low_z_offset_3.mp4
# === VIDEO ANALYSIS ===
# Video: c:\Users\bgmanuel\MasterInteligenciaArtificial\Periodo2\TFM\Super-Resolution-Images-for-3D-Printing-Defect-Detection\data\videos\low_z_offset\low_z_offset_3.mp4
# Total frames: 1302
# Images saved in this run: 17
# Total images in directory: 105
# Original HR frame size (width x height): 478 x 850
# Cropped HR frame size (width x height): 478 x 478
# LR frame size (width x height): 239 x 239
#   (7/12) low_z_offset_4.mp4
# === VIDEO ANALYSIS ===
# Video: c:\Users\bgmanuel\MasterInteligenciaArtificial\Periodo2\TFM\Super-Resolution-Images-for-3D-Printing-Defect-Detection\data\videos\low_z_offset\low_z_offset_4.mp4
# Total frames: 1325
# Images saved in this run: 17
# Total images in directory: 122
# Original HR frame size (width x height): 478 x 850
# Cropped HR frame size (width x height): 478 x 478
# LR frame size (width x height): 239 x 239
#   (8/12) low_z_offset_5.mp4
# === VIDEO ANALYSIS ===
# Video: c:\Users\bgmanuel\MasterInteligenciaArtificial\Periodo2\TFM\Super-Resolution-Images-for-3D-Printing-Defect-Detection\data\videos\low_z_offset\low_z_offset_5.mp4
# Total frames: 1419
# Images saved in this run: 18
# Total images in directory: 140
# Original HR frame size (width x height): 478 x 850
# Cropped HR frame size (width x height): 478 x 478
# LR frame size (width x height): 239 x 239
#   (9/12) low_z_offset_6.mp4
# === VIDEO ANALYSIS ===
# Video: c:\Users\bgmanuel\MasterInteligenciaArtificial\Periodo2\TFM\Super-Resolution-Images-for-3D-Printing-Defect-Detection\data\videos\low_z_offset\low_z_offset_6.mp4
# Total frames: 1135
# Images saved in this run: 15
# Total images in directory: 155
# Original HR frame size (width x height): 478 x 850
# Cropped HR frame size (width x height): 478 x 478
# LR frame size (width x height): 239 x 239
#   (10/12) low_z_offset_7.mp4
# === VIDEO ANALYSIS ===
# Video: c:\Users\bgmanuel\MasterInteligenciaArtificial\Periodo2\TFM\Super-Resolution-Images-for-3D-Printing-Defect-Detection\data\videos\low_z_offset\low_z_offset_7.mp4
# Total frames: 1064
# Images saved in this run: 14
# Total images in directory: 169
# Original HR frame size (width x height): 478 x 850
# Cropped HR frame size (width x height): 478 x 478
# LR frame size (width x height): 239 x 239
#   (11/12) low_z_offset_8.mp4
# === VIDEO ANALYSIS ===
# Video: c:\Users\bgmanuel\MasterInteligenciaArtificial\Periodo2\TFM\Super-Resolution-Images-for-3D-Printing-Defect-Detection\data\videos\low_z_offset\low_z_offset_8.mp4
# Total frames: 1026
# Images saved in this run: 13
# Total images in directory: 182
# Original HR frame size (width x height): 478 x 850
# Cropped HR frame size (width x height): 478 x 478
# LR frame size (width x height): 239 x 239
#   (12/12) low_z_offset_9.mp4
# === VIDEO ANALYSIS ===
# Video: c:\Users\bgmanuel\MasterInteligenciaArtificial\Periodo2\TFM\Super-Resolution-Images-for-3D-Printing-Defect-Detection\data\videos\low_z_offset\low_z_offset_9.mp4
# Total frames: 1175
# Images saved in this run: 15
# Total images in directory: 197
# Original HR frame size (width x height): 478 x 850
# Cropped HR frame size (width x height): 478 x 478
# LR frame size (width x height): 239 x 239
#
# [high_z_offset] class 1 | 12 video(s), one frame every 50
#   (1/12) high_z_offset_1.mp4
# === VIDEO ANALYSIS ===
# Video: c:\Users\bgmanuel\MasterInteligenciaArtificial\Periodo2\TFM\Super-Resolution-Images-for-3D-Printing-Defect-Detection\data\videos\high_z_offset\high_z_offset_1.mp4
# Total frames: 597
# Images saved in this run: 12
# Total images in directory: 12
# Original HR frame size (width x height): 478 x 850
# Cropped HR frame size (width x height): 478 x 478
# LR frame size (width x height): 239 x 239
#   (2/12) high_z_offset_10.mp4
# === VIDEO ANALYSIS ===
# Video: c:\Users\bgmanuel\MasterInteligenciaArtificial\Periodo2\TFM\Super-Resolution-Images-for-3D-Printing-Defect-Detection\data\videos\high_z_offset\high_z_offset_10.mp4
# Total frames: 716
# Images saved in this run: 15
# Total images in directory: 27
# Original HR frame size (width x height): 478 x 850
# Cropped HR frame size (width x height): 478 x 478
# LR frame size (width x height): 239 x 239
#   (3/12) high_z_offset_11.mp4
# === VIDEO ANALYSIS ===
# Video: c:\Users\bgmanuel\MasterInteligenciaArtificial\Periodo2\TFM\Super-Resolution-Images-for-3D-Printing-Defect-Detection\data\videos\high_z_offset\high_z_offset_11.mp4
# Total frames: 661
# Images saved in this run: 14
# Total images in directory: 41
# Original HR frame size (width x height): 478 x 850
# Cropped HR frame size (width x height): 478 x 478
# LR frame size (width x height): 239 x 239
#   (4/12) high_z_offset_12.mp4
# === VIDEO ANALYSIS ===
# Video: c:\Users\bgmanuel\MasterInteligenciaArtificial\Periodo2\TFM\Super-Resolution-Images-for-3D-Printing-Defect-Detection\data\videos\high_z_offset\high_z_offset_12.mp4
# Total frames: 646
# Images saved in this run: 13
# Total images in directory: 54
# Original HR frame size (width x height): 478 x 850
# Cropped HR frame size (width x height): 478 x 478
# LR frame size (width x height): 239 x 239
#   (5/12) high_z_offset_2.mp4
# === VIDEO ANALYSIS ===
# Video: c:\Users\bgmanuel\MasterInteligenciaArtificial\Periodo2\TFM\Super-Resolution-Images-for-3D-Printing-Defect-Detection\data\videos\high_z_offset\high_z_offset_2.mp4
# Total frames: 701
# Images saved in this run: 15
# Total images in directory: 69
# Original HR frame size (width x height): 478 x 850
# Cropped HR frame size (width x height): 478 x 478
# LR frame size (width x height): 239 x 239
#   (6/12) high_z_offset_3.mp4
# === VIDEO ANALYSIS ===
# Video: c:\Users\bgmanuel\MasterInteligenciaArtificial\Periodo2\TFM\Super-Resolution-Images-for-3D-Printing-Defect-Detection\data\videos\high_z_offset\high_z_offset_3.mp4
# Total frames: 582
# Images saved in this run: 12
# Total images in directory: 81
# Original HR frame size (width x height): 478 x 850
# Cropped HR frame size (width x height): 478 x 478
# LR frame size (width x height): 239 x 239
#   (7/12) high_z_offset_4.mp4
# === VIDEO ANALYSIS ===
# Video: c:\Users\bgmanuel\MasterInteligenciaArtificial\Periodo2\TFM\Super-Resolution-Images-for-3D-Printing-Defect-Detection\data\videos\high_z_offset\high_z_offset_4.mp4
# Total frames: 703
# Images saved in this run: 15
# Total images in directory: 96
# Original HR frame size (width x height): 478 x 850
# Cropped HR frame size (width x height): 478 x 478
# LR frame size (width x height): 239 x 239
#   (8/12) high_z_offset_5.mp4
# === VIDEO ANALYSIS ===
# Video: c:\Users\bgmanuel\MasterInteligenciaArtificial\Periodo2\TFM\Super-Resolution-Images-for-3D-Printing-Defect-Detection\data\videos\high_z_offset\high_z_offset_5.mp4
# Total frames: 631
# Images saved in this run: 13
# Total images in directory: 109
# Original HR frame size (width x height): 478 x 850
# Cropped HR frame size (width x height): 478 x 478
# LR frame size (width x height): 239 x 239
#   (9/12) high_z_offset_6.mp4
# === VIDEO ANALYSIS ===
# Video: c:\Users\bgmanuel\MasterInteligenciaArtificial\Periodo2\TFM\Super-Resolution-Images-for-3D-Printing-Defect-Detection\data\videos\high_z_offset\high_z_offset_6.mp4
# Total frames: 591
# Images saved in this run: 12
# Total images in directory: 121
# Original HR frame size (width x height): 478 x 850
# Cropped HR frame size (width x height): 478 x 478
# LR frame size (width x height): 239 x 239
#   (10/12) high_z_offset_7.mp4
# === VIDEO ANALYSIS ===
# Video: c:\Users\bgmanuel\MasterInteligenciaArtificial\Periodo2\TFM\Super-Resolution-Images-for-3D-Printing-Defect-Detection\data\videos\high_z_offset\high_z_offset_7.mp4
# Total frames: 647
# Images saved in this run: 13
# Total images in directory: 134
# Original HR frame size (width x height): 478 x 850
# Cropped HR frame size (width x height): 478 x 478
# LR frame size (width x height): 239 x 239
#   (11/12) high_z_offset_8.mp4
# === VIDEO ANALYSIS ===
# Video: c:\Users\bgmanuel\MasterInteligenciaArtificial\Periodo2\TFM\Super-Resolution-Images-for-3D-Printing-Defect-Detection\data\videos\high_z_offset\high_z_offset_8.mp4
# Total frames: 722
# Images saved in this run: 15
# Total images in directory: 149
# Original HR frame size (width x height): 478 x 850
# Cropped HR frame size (width x height): 478 x 478
# LR frame size (width x height): 239 x 239
#   (12/12) high_z_offset_9.mp4
# === VIDEO ANALYSIS ===
# Video: c:\Users\bgmanuel\MasterInteligenciaArtificial\Periodo2\TFM\Super-Resolution-Images-for-3D-Printing-Defect-Detection\data\videos\high_z_offset\high_z_offset_9.mp4
# Total frames: 664
# Images saved in this run: 14
# Total images in directory: 163
# Original HR frame size (width x height): 478 x 850
# Cropped HR frame size (width x height): 478 x 478
# LR frame size (width x height): 239 x 239
#
# Videos processed per folder: {'low_z_offset': 12, 'high_z_offset': 12}
# Images saved per folder: {'low_z_offset': 197, 'high_z_offset': 163}
# Total HR/LR pairs: 360

# %% [markdown]
# ## Sample images of the created dataset

# %%
_ = plot_hr_lr_samples()
