# %% [markdown]
# # HR/LR dataset creation
#
# Extracts frames from the source videos, crops them to the object and writes
# each HR image next to its degraded LR counterpart.
#
# The logic lives in `srlib/dataset/builder.py` and the knobs live in
# `srlib/constants.py`: the degradation seed picks *which* dataset is drawn
# and the degradation config picks *how* degraded it is. To search for a
# realistic LR dataset, tune the config there, delete `data/images/HR`,
# `data/images/LR` and `data/metadata/degradation_log.json`, and re-run this
# notebook.

# %%
import os
import sys

sys.path.append(os.path.abspath(os.path.join(os.getcwd(), "../")))

from srlib.dataset.builder import build_dataset_from_videos
from srlib.dataset.visualization import plot_hr_lr_samples

# %% [markdown]
# ## Build the dataset

# %%
# Defaults come from constants: which folders to walk, how many videos to
# take from each, the frame interval, the class ids, the degradation seed and
# config, and whether to replay the recorded log instead of sampling.
summary = build_dataset_from_videos()
# Out:
# ================================================================
#  Dataset build | seed 42, scale 0.5
# ================================================================
#
#   low_z_offset  (class 0, 12 videos, 1 frame every 39)
#     low_z_offset_1.mp4             1597 frames ->  41 pairs
#     low_z_offset_10.mp4            1136 frames ->  30 pairs
#     low_z_offset_11.mp4            1397 frames ->  36 pairs
#     low_z_offset_12.mp4            1461 frames ->  38 pairs
#     low_z_offset_2.mp4             1268 frames ->  33 pairs
#     low_z_offset_3.mp4             1302 frames ->  34 pairs
#     low_z_offset_4.mp4             1325 frames ->  34 pairs
#     low_z_offset_5.mp4             1419 frames ->  36 pairs (1 blank)
#     low_z_offset_6.mp4             1135 frames ->  30 pairs
#     low_z_offset_7.mp4             1064 frames ->  27 pairs (1 blank)
#     low_z_offset_8.mp4             1026 frames ->  27 pairs
#     low_z_offset_9.mp4             1175 frames ->  31 pairs
#     -> HR 478x478  LR 239x239
#     -> 397 pairs from 12 videos, 2 blank frames discarded
#
#   high_z_offset  (class 1, 12 videos, 1 frame every 20)
#     high_z_offset_1.mp4             597 frames ->  30 pairs
#     high_z_offset_10.mp4            716 frames ->  36 pairs
#     high_z_offset_11.mp4            661 frames ->  34 pairs
#     high_z_offset_12.mp4            646 frames ->  33 pairs
#     high_z_offset_2.mp4             701 frames ->  36 pairs
#     high_z_offset_3.mp4             582 frames ->  30 pairs
#     high_z_offset_4.mp4             703 frames ->  36 pairs
#     high_z_offset_5.mp4             631 frames ->  32 pairs
#     high_z_offset_6.mp4             591 frames ->  30 pairs
#     high_z_offset_7.mp4             647 frames ->  33 pairs
#     high_z_offset_8.mp4             722 frames ->  37 pairs
#     high_z_offset_9.mp4             664 frames ->  34 pairs
#     -> HR 478x478  LR 239x239
#     -> 401 pairs from 12 videos
#
#   TOTAL     798 HR/LR pairs from 24 videos
#   done in 41.7s

# %% [markdown]
# ## Sample images of the created dataset

# %%
_ = plot_hr_lr_samples()
