# %% [markdown]
# # Exploratory data analysis of the HR/LR dataset
#
# Measures how far each LR image is from its HR reference and writes the
# figures under `results/eda`. The logic lives in `srlib/eda.py`.
#
# Every LR image is brought up to the HR frame with a single declared
# interpolation, the same one SRCNN is fed. The per-image degradation kernel
# recorded in the degradation log is deliberately not used: an LR capture in
# the wild does not come with the filter that produced it, and measuring each
# image under a different kernel would make them incomparable with each other.

# %%
import os
import sys

sys.path.append(os.path.abspath(os.path.join(os.getcwd(), "../")))

from srlib.eda import EDAPipeline

# %% [markdown]
# ## Run the analysis

# %%
# Paths default to the dataset roots declared in constants.
pipeline = EDAPipeline()

df = pipeline.run()
df
# Out:
# ================================================================
#  EDA | GLCM 32 levels, 1 angle
# ================================================================
#   computing per-pair metrics
# Computing metrics: 100%|██████████| 358/358 [01:19<00:00,  4.48img/s]
#   metrics   358 pairs x 10 variables
#   rendering dataset panels
#   rendering 1 best and worst LPIPS pairs
#   figures   written to c:\Users\bgmanuel\MasterInteligenciaArtificial\Periodo2\TFM\Super-Resolution-Images-for-3D-Printing-Defect-Detection\results\eda
#   done in 1m 32.1s
#                                filename     lpips       psnr      ssim  \
# 0      high_z_offset/high_z_offset0.png  0.580798  21.718990  0.595718
# 1      high_z_offset/high_z_offset1.png  0.206130  27.883513  0.893078
# 2     high_z_offset/high_z_offset10.png  0.240214  26.155903  0.840868
# 3    high_z_offset/high_z_offset100.png  0.323946  27.658186  0.832598
# 4    high_z_offset/high_z_offset101.png  0.365749  25.963576  0.743941
# ..                                  ...       ...        ...       ...
# 353     low_z_offset/low_z_offset95.png  0.387703  28.673220  0.721101
# 354     low_z_offset/low_z_offset96.png  0.234779  37.665449  0.906807
# 355     low_z_offset/low_z_offset97.png  0.368499  29.039156  0.748279
# 356     low_z_offset/low_z_offset98.png  0.326062  36.355883  0.891177
# 357     low_z_offset/low_z_offset99.png  0.225023  34.688508  0.909340
#
#      lap_var_lr   lap_var_hr  ringing_lr  ringing_hr  glcm_contrast  \
# 0    104.885896  2130.067658   35.963183   43.524760       1.326281
# 1    172.240590  1070.877575   41.496793   43.775671       1.350096
# 2    254.373918   812.430081   43.544129   44.400967       1.991040
# 3    138.939833   998.157010   33.938035   33.862938       1.265668
# 4     97.298117   681.868354   38.808355   39.280730       1.070358
# ..          ...          ...         ...         ...            ...
# 353   13.270842   323.668931   28.784452   29.285557       0.183653
# 354    9.712028    13.154399    0.000000   37.919749       0.151285
# 355   14.071826   183.334147   31.268505   28.580194       0.153803
# 356   10.994232    13.176352    0.000000   26.662338       0.173482
# 357    8.043250    26.328602   28.172176   31.167453       0.127361
#
#      saturation_mean_lr  saturation_mean_hr
# 0             26.403805           19.074198
# 1             20.370166           20.932704
# 2             23.675141           25.198631
# 3             16.719118           16.002906
# 4             18.954430           19.318591
# ..                  ...                 ...
# 353           13.936013           13.084360
# 354           15.693178           15.049544
# 355           16.331870           16.395249
# 356           21.999659           21.913381
# 357           14.884421           15.977570
#
# [358 rows x 11 columns]

# %% [markdown]
# ## Descriptive statistics

# %%
from srlib.eda import StatsReporter

StatsReporter.summary(df)
# Out:
#                           mean         std         25%         50%         75%
# lpips                 0.361632    0.118482    0.280063    0.348699    0.429848
# psnr                 27.618499    3.297008   25.284653   27.433273   29.544965
# ssim                  0.751323    0.100735    0.694482    0.758600    0.821195
# lap_var_lr           72.351404   76.009513   25.194046   48.349791   88.031386
# lap_var_hr          611.901930  570.357445  242.232369  425.436554  850.760872
# ringing_lr           32.286270    6.899647   28.855942   32.412155   36.231976
# ringing_hr           33.838997    6.473659   28.808200   32.777173   38.582231
# glcm_contrast         0.791599    0.685427    0.348257    0.605214    0.951435
# saturation_mean_lr   18.359966    4.869073   14.977223   17.961921   21.221066
# saturation_mean_hr   19.135533    4.641669   15.864144   18.464394   21.749174
