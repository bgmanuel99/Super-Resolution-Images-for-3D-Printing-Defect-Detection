# %% [markdown]
# # Exploratory data analysis of the HR/LR dataset
#
# Measures how far each LR image is from its HR reference and writes the
# figures under `results/eda`. The logic lives in `srlib/eda.py`.
#
# Every LR image is brought up to the HR frame with a single declared
# interpolation, the same one SRCNN is fed. The per-image degradation kernel
# recorded in the degradation log is deliberately not used: an LR capture in
# the wild does not come with the filter that produced it, and measuring each
# image under a different kernel would make them incomparable with each other.

# %%
import os
import sys

sys.path.append(os.path.abspath(os.path.join(os.getcwd(), "../")))

from srlib.eda import EDAPipeline

# %% [markdown]
# ## Run the analysis

# %%
# Paths default to the dataset roots declared in constants.
pipeline = EDAPipeline(glcm_multi_angle=True, glcm_levels=32)

df = pipeline.run()
df
# Out:
# ...
#  EDA | GLCM 32 levels, 4 angles
# ...
#   computing per-pair metrics
# Computing metrics:   0%|          | 0/360 [00:00<?, ?img/s]
# Setting up [LPIPS] perceptual loss: trunk [alex], v[0.1], spatial [off]
# c:\Users\bgmanuel\anaconda3\envs\py310\lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# c:\Users\bgmanuel\anaconda3\envs\py310\lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=AlexNet_Weights.IMAGENET1K_V1`. You can also use `weights=AlexNet_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Loading model from: c:\Users\bgmanuel\anaconda3\envs\py310\lib\site-packages\lpips\weights\v0.1\alex.pth
# ...

# %% [markdown]
# ## Descriptive statistics

# %%
from srlib.eda import StatsReporter

StatsReporter.summary(df)
# Out:
#                           mean         std         25%         50%         75%
# lpips                 0.360248    0.118662    0.283190    0.349880    0.437688
# psnr                 27.920214    5.304418   25.299988   27.413528   29.548116
# ssim                  0.752440    0.100632    0.689951    0.757669    0.822105
# lap_var_lr           71.867461   75.491102   24.961768   47.885685   88.786076
# lap_var_hr          608.502480  570.587109  237.640287  424.621476  850.308196
# ringing_lr           32.143903    7.313171   28.889349   32.420338   36.123193
# ringing_hr           33.651003    6.929546   28.680097   32.746171   38.556227
# glcm_contrast         1.204620    0.848393    0.611605    0.985819    1.570267
# saturation_mean_lr   18.273125    5.063732   14.936968   18.043220   21.303518
# saturation_mean_hr   19.029224    4.842899   15.726664   18.448679   21.698914
